# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. Data

# %% [markdown]
# ### 1.1. OXCGRT Data

# %%
data = pd.read_csv('../Data/Covid19_All_20210710.csv', low_memory=False, index_col=0)

# %% [markdown]
# ### 1.2. Continent Data

# %%
continent = pd.read_csv('../Data/continent_data.csv', low_memory=False, index_col=0)
continent = continent[['Continent_Name', 'Three_Letter_Country_Code']]
continent.columns = ['ContinentName', 'CountryCode']

# add Kosovo
continent = continent.append({'ContinentName': 'Europe', 
                              'CountryCode': 'RKS'}, ignore_index=True)

# %% [markdown]
# # 2. Merge

# %%
data_merged = data.merge(continent, how='left', on='CountryCode')

# %% [markdown]
# # 3. Filtering

# %%
cols = ['CountryName', 'ContinentName', 'RegionName', 'Date', 'C1_School closing',
       'C2_Workplace closing', 'C3_Cancel public events', 
       'C4_Restrictions on gatherings', 'C5_Close public transport',
       'C6_Stay at home requirements', 'C7_Restrictions on internal movement', 
       'C8_International travel controls', 'E1_Income support',
       'E2_Debt/contract relief', 'E3_Fiscal measures',
       'E4_International support', 'H1_Public information campaigns', 
       'H2_Testing policy', 'H3_Contact tracing', 'H4_Emergency investment in healthcare', 
       'H5_Investment in vaccines', 'H6_Facial Coverings', 
       'H7_Vaccination policy', 'H8_Protection of elderly people', 
       'ConfirmedCases', 'ConfirmedDeaths']

# %% [markdown]
# ### Asia

# %%
asia = data_merged.loc[data_merged.ContinentName == 'Asia', cols]

# %%
asia.sample(5)
# Out:
#         CountryName ContinentName RegionName        Date  C1_School closing  \
# 89164        Israel          Asia        NaN  2020-02-14                0.0
# 90909        Jordan          Asia        NaN  2020-04-28                3.0
# 49316         China          Asia    Jiangsu  2020-10-27                0.0
# 137358  Timor-Leste          Asia        NaN  2020-12-02                1.0
# 48399         China          Asia      Hunan  2021-05-12                1.0
#
#         C2_Workplace closing  C3_Cancel public events  \
# 89164                    0.0                      0.0
# 90909                    2.0                      2.0
# 49316                    1.0                      1.0
# 137358                   0.0                      0.0
# 48399                    1.0                      1.0
#
#         C4_Restrictions on gatherings  C5_Close public transport  \
# 89164                             0.0                        0.0
# 90909                             4.0                        2.0
# 49316                             1.0                        1.0
# 137358                            0.0                        0.0
# 48399                             0.0                        0.0
#
#         C6_Stay at home requirements  ...  H1_Public information campaigns  \
# 89164                            0.0  ...                              2.0
# 90909                            2.0  ...                              2.0
# 49316                            1.0  ...                              2.0
# 137358                           2.0  ...                              2.0
# 48399                            0.0  ...                              2.0
#
#         H2_Testing policy  H3_Contact tracing  \
# 89164                 1.0                 0.0
# 90909                 2.0                 1.0
# 49316                 2.0                 2.0
# 137358                3.0                 2.0
# 48399                 3.0                 2.0
#
#         H4_Emergency investment in healthcare  H5_Investment in vaccines  \
# 89164                                     0.0                        1.0
# 90909                                     0.0                        0.0
# 49316                                     0.0                        0.0
# 137358                                    0.0                        0.0
# 48399                                     0.0                        0.0
#
#         H6_Facial Coverings  H7_Vaccination policy  \
# 89164                   0.0                    0.0
# 90909                   0.0                    0.0
# 49316                   3.0                    0.0
# 137358                  3.0                    0.0
# 48399                   2.0                    4.0
#
#         H8_Protection of elderly people  ConfirmedCases  ConfirmedDeaths
# 89164                               0.0             0.0              0.0
# 90909                               2.0           449.0              8.0
# 49316                               2.0           670.0              0.0
# 137358                              0.0            31.0              0.0
# 48399                               1.0          1046.0              4.0
#
# [5 rows x 26 columns]

# %%
asia.to_csv('Asia_covid19_20210710.csv')

# %% [markdown]
# ### Europe

# %%
europe = data_merged.loc[data_merged.ContinentName == 'Europe', cols]

# %%
europe.sample(5)
# Out:
#        CountryName ContinentName RegionName        Date  C1_School closing  \
# 106145       Malta        Europe        NaN  2020-11-11                1.0
# 4783       Austria        Europe        NaN  2020-11-23                3.0
# 89109      Iceland        Europe        NaN  2021-06-30                2.0
# 77803      Georgia        Europe        NaN  2020-07-09                3.0
# 132251      Sweden        Europe        NaN  2020-08-30                1.0
#
#         C2_Workplace closing  C3_Cancel public events  \
# 106145                   2.0                      2.0
# 4783                     3.0                      2.0
# 89109                    0.0                      0.0
# 77803                    2.0                      2.0
# 132251                   1.0                      2.0
#
#         C4_Restrictions on gatherings  C5_Close public transport  \
# 106145                            4.0                        0.0
# 4783                              4.0                        1.0
# 89109                             0.0                        0.0
# 77803                             4.0                        0.0
# 132251                            3.0                        1.0
#
#         C6_Stay at home requirements  ...  H1_Public information campaigns  \
# 106145                           0.0  ...                              2.0
# 4783                             2.0  ...                              2.0
# 89109                            0.0  ...                              2.0
# 77803                            1.0  ...                              2.0
# 132251                           1.0  ...                              2.0
#
#         H2_Testing policy  H3_Contact tracing  \
# 106145                3.0                 2.0
# 4783                  3.0                 2.0
# 89109                 3.0                 2.0
# 77803                 2.0                 2.0
# 132251                2.0                 1.0
#
#         H4_Emergency investment in healthcare  H5_Investment in vaccines  \
# 106145                                    NaN                        NaN
# 4783                                      0.0                        0.0
# 89109                                     0.0                        0.0
# 77803                                     0.0                        0.0
# 132251                                    0.0                        0.0
#
#         H6_Facial Coverings  H7_Vaccination policy  \
# 106145                  4.0                    0.0
# 4783                    3.0                    0.0
# 89109                   0.0                    5.0
# 77803                   2.0                    0.0
# 132251                  0.0                    0.0
#
#         H8_Protection of elderly people  ConfirmedCases  ConfirmedDeaths
# 106145                              2.0          7537.0             88.0
# 4783                                3.0        250333.0           2459.0
# 89109                               0.0          6555.0             29.0
# 77803                               1.0           968.0             15.0
# 132251                              3.0         83958.0           5821.0
#
# [5 rows x 26 columns]

# %%
europe.to_csv('Europe_covid19_20210710.csv')

# %% [markdown]
# ### USA

# %%
usa = data_merged.loc[data_merged.CountryName == 'United States']

# %%
usa.sample(5)
# Out:
#           CountryName CountryCode   RegionName RegionCode Jurisdiction  \
# 151961  United States         USA     Illinois      US_IL  STATE_TOTAL
# 153714  United States         USA     Kentucky      US_KY  STATE_TOTAL
# 163562  United States         USA         Ohio      US_OH  STATE_TOTAL
# 157800  United States         USA  Mississippi      US_MS  STATE_TOTAL
# 153849  United States         USA    Louisiana      US_LA  STATE_TOTAL
#
#               Date  C1_School closing  C1_Flag  C2_Workplace closing  C2_Flag  \
# 151961  2021-04-02                2.0      0.0                   1.0      1.0
# 153714  2021-06-23                NaN      NaN                   1.0      1.0
# 163562  2020-12-27                2.0      0.0                   1.0      1.0
# 157800  2020-06-18                3.0      1.0                   1.0      1.0
# 153849  2020-04-27                3.0      1.0                   2.0      1.0
#
#         ...  StringencyIndexForDisplay  StringencyLegacyIndex  \
# 151961  ...                      51.85                  58.33
# 153714  ...                      34.26                  51.19
# 163562  ...                      58.33                  64.29
# 157800  ...                      62.96                  76.90
# 153849  ...                      75.93                  79.76
#
#         StringencyLegacyIndexForDisplay  GovernmentResponseIndex  \
# 151961                            58.33                    60.78
# 153714                            51.19                      NaN
# 163562                            64.29                    61.35
# 157800                            76.90                    57.55
# 153849                            79.76                    65.89
#
#         GovernmentResponseIndexForDisplay  ContainmentHealthIndex  \
# 151961                              60.78                   60.54
# 153714                                NaN                   39.88
# 163562                              61.35                   64.76
# 157800                              57.55                   56.85
# 153849                              65.89                   62.80
#
#         ContainmentHealthIndexForDisplay  EconomicSupportIndex  \
# 151961                             60.54                  62.5
# 153714                             39.88                   NaN
# 163562                             64.76                  37.5
# 157800                             56.85                  62.5
# 153849                             62.80                  87.5
#
#         EconomicSupportIndexForDisplay  ContinentName
# 151961                            62.5  North America
# 153714                             NaN  North America
# 163562                            37.5  North America
# 157800                            62.5  North America
# 153849                            87.5  North America
#
# [5 rows x 52 columns]

# %%
usa.to_csv('../Data/Covid19_USA.csv')
