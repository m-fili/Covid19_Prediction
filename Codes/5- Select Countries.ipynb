# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %%
europe = pd.read_csv('../Data/Covid19_Europe_20210710.csv', 
                       parse_dates=['Date'],
                       index_col=0, 
                       low_memory=False)

# %%
vaccination = pd.read_csv("../Data/Vaccination.csv", index_col=0)
# Out:
#           location iso_code        date  people_vaccinated  \
# 0      Afghanistan      AFG  2021-02-22                0.0
# 1      Afghanistan      AFG  2021-02-23                NaN
# 2      Afghanistan      AFG  2021-02-24                NaN
# 3      Afghanistan      AFG  2021-02-25                NaN
# 4      Afghanistan      AFG  2021-02-26                NaN
# ...            ...      ...         ...                ...
# 33202     Zimbabwe      ZWE  2021-07-09           875182.0
# 33203     Zimbabwe      ZWE  2021-07-10                NaN
# 33204     Zimbabwe      ZWE  2021-07-11           895980.0
# 33205     Zimbabwe      ZWE  2021-07-12           926312.0
# 33206     Zimbabwe      ZWE  2021-07-13           955656.0
#
#        people_fully_vaccinated  daily_vaccinations
# 0                          NaN                 NaN
# 1                          NaN              1367.0
# 2                          NaN              1367.0
# ...

# %% [markdown]
# # Functions

# %%
def plot(df, country):
    
    df['NewCases'] = df.ConfirmedCases.diff().fillna(0)
    df.loc[df.CountryName == country, ['NewCases', 'Date']].set_index('Date').plot()
    
    plt.title(country, size=16)

# %%
def plot_vaccine(df, country):
    
    df.loc[df.location == country, ['date', 'daily_vaccinations']].set_index('date').plot()

# %% [markdown]
# ### Visualization

# %%
countries = ['Italy', 'France', 'Germany', 'United Kingdom', 'Denmark', 'Portugal', 'Greece']

for country in countries:
    plot(europe, country)

# %%
countries = ['Italy', 'France', 'Germany', 'United Kingdom', 'Denmark', 'Portugal', 'Greece']

for country in countries:
    plot_vaccine(vaccination, country)
